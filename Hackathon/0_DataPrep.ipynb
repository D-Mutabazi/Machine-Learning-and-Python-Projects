# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_og = pd.read_csv('data/billing_data.csv', index_col='usage_end_time', parse_dates=True)

# %%
df = df_og.copy()

sum_df = df.groupby(df.index).count()

sum_df
# Out:
#                      cost  service_type  region  usage_amount  usage_unit
# usage_end_time
# 2023-12-07 09:00:00    67            67      61            67          67
# 2023-12-07 10:00:00    96            96      90            96          96
# 2023-12-07 11:00:00    85            85      78            85          85
# 2023-12-07 12:00:00    98            98      94            98          98
# 2023-12-07 13:00:00    83            83      77            83          83
# ...                   ...           ...     ...           ...         ...
# 2024-08-15 22:00:00   110           110      90           110         110
# 2024-08-15 23:00:00    75            75      65            75          75
# 2024-08-16 00:00:00    78            78      68            78          78
# 2024-08-16 01:00:00    67            67      46            67          67
# 2024-08-16 02:00:00    11            11       6            11          11
#
# [6066 rows x 5 columns]

# %%
df_service = df.groupby('service_type').count()

plt.bar(df_service.index, df_service['cost'])
plt.xticks(rotation = 90)
plt.show()

# %%
# Based on the usage unit, what are the boxplots of the cost

plt.figure(figsize=(10, 6))
sns.boxplot(x='usage_unit', y='cost', data=df)
plt.title('Boxplot of Cost by Usage Unit')
plt.xlabel('Usage Unit')
plt.ylabel('Cost (USD)')
plt.yscale('log')  # Optional: If there are outliers or a wide range, use log scale for better visualization
plt.show()
